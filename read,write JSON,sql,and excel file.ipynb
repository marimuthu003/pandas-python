# %%
import pandas as pd
df=pd.read_csv('data_2023/survey_results_public.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
pd.set_option('display.max_columns',84)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
filt=df['Country']=='India'
india_df=df[filt]

# %%
india_df.head(10)
# Out:
#      ResponseId     Q120                      MainBranch              Age  \
# 9            10  I agree  I am a developer by profession  25-34 years old
# 66           67  I agree  I am a developer by profession  25-34 years old
# 78           79  I agree  I am a developer by profession  18-24 years old
# 82           83  I agree  I am a developer by profession  25-34 years old
# 85           86  I agree  I am a developer by profession  25-34 years old
# 105         106  I agree           I am learning to code  18-24 years old
# 127         128  I agree  I am a developer by profession  25-34 years old
# 135         136  I agree  I am a developer by profession  18-24 years old
# 172         173  I agree  I am a developer by profession  18-24 years old
# 177         178  I agree  I am a developer by profession  35-44 years old
#
#                                             Employment  \
# 9                   Not employed, but looking for work
# ...

# %%
#create csv file in pandas:
india_df.to_csv('data_2023/modified.csv',sep='\t')

# %%
india_df=pd.read_csv('data_2023/modified.csv')
india_df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 india_df=pd.read_csv('data_2023/modified.csv')
#       2 india_df
#
# File d:\Muthu\pandas-python\venv\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#create the excel file:
india_df.to_excel('data_2023/modified.xlsx')

# %%
india_df=pd.read_excel('data_2023/modified.xlsx')
india_df.head(10)
# Out:
#    Unnamed: 0  ResponseId     Q120                      MainBranch  \
# 0           9          10  I agree  I am a developer by profession
# 1          66          67  I agree  I am a developer by profession
# 2          78          79  I agree  I am a developer by profession
# 3          82          83  I agree  I am a developer by profession
# 4          85          86  I agree  I am a developer by profession
# 5         105         106  I agree           I am learning to code
# 6         127         128  I agree  I am a developer by profession
# 7         135         136  I agree  I am a developer by profession
# 8         172         173  I agree  I am a developer by profession
# 9         177         178  I agree  I am a developer by profession
#
#                Age                                         Employment  \
# 0  25-34 years old                 Not employed, but looking for work
# 1  25-34 years old                                Employed, full-time
# ...

# %%
#create json file:
india_df.to_json('data_2023/modified.json',orient='records',lines=True)

# %%
india_df=pd.read_json('data_2023/modified.json',orient='records',lines=True)
india_df.head()
# Out:
#    Unnamed: 0  ResponseId     Q120                      MainBranch  \
# 0           9          10  I agree  I am a developer by profession
# 1          66          67  I agree  I am a developer by profession
# 2          78          79  I agree  I am a developer by profession
# 3          82          83  I agree  I am a developer by profession
# 4          85          86  I agree  I am a developer by profession
#
#                Age                          Employment  \
# 0  25-34 years old  Not employed, but looking for work
# 1  25-34 years old                 Employed, full-time
# 2  18-24 years old                 Employed, full-time
# 3  25-34 years old                 Employed, full-time
# 4  25-34 years old                 Employed, full-time
#
#                              RemoteWork  \
# 0                                  None
# 1  Hybrid (some remote, some in-person)
# 2                                Remote
# 3  Hybrid (some remote, some in-person)
# ...

# %%
from sqlalchemy import create_engine
import psycopg2
engine=create_engine('postgresssql://dbuser:dbpass')
